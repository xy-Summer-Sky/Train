# %%
import pandas as pd

# Define file paths
QUERY_DIR = '/root/train/Train/A/A_question.csv'
SUB_DIR = '/root/train/Train/submit_example.csv'

# Read CSV files with additional parameters
try:
    query = pd.read_csv(QUERY_DIR, dtype=str, na_values=['', 'NA'], encoding='utf-8')
    sub = pd.read_csv(SUB_DIR, dtype=str, na_values=['', 'NA'], encoding='utf-8')
    print(query.head(3))
    print(sub.head(3))
except Exception as e:
    print(f"Error reading CSV files: {e}")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.0rc1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/root/miniconda3/envs/train310/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/root/miniconda3/envs/train310/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/root/miniconda3/envs/train310/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
# ...
